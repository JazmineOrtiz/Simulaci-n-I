# %% [markdown]
# <a href="https://colab.research.google.com/github/JazmineOrtiz/Simulaci-n-I/blob/main/Generador%20Congruencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate
lista_principal = []
m = float(input("dame el valor de m: "))
xo = float(input("dame el valor de la semilla (xo): "))
a = float(input("dame el valor de a: "))
c = float(input("dame el valor de c: "))
x=0
for x in range(30):
  #print("primera columna: ", xo)
  xnn=(a*xo)+c
  #print("segunda columna: ", xnn)
  mod=xnn%m
  #print("tercera columna: ", mod)
  division=xo/m
  #print("cuarta columna: ", division)
  #tabla=[[x,xo,xnn,mod,division]]
  #print(tabulate(tabla))
  lista_principal.append([x, xo, xnn, mod, division])
  xo=mod
headers = ["x", "xo", "xnn", "mod","división"]
print(tabulate(lista_principal, headers=headers, tablefmt="grid"))
# Out:
# dame el valor de m: 16
# dame el valor de la semilla (xo): 6
# dame el valor de a: 5
# dame el valor de c: 5
# +-----+------+-------+-------+------------+
# |   x |   xo |   xnn |   mod |   división |
# +=====+======+=======+=======+============+
# |   0 |    6 |    35 |     3 |     0.375  |
# +-----+------+-------+-------+------------+
# |   1 |    3 |    20 |     4 |     0.1875 |
# +-----+------+-------+-------+------------+
# |   2 |    4 |    25 |     9 |     0.25   |
# +-----+------+-------+-------+------------+
# |   3 |    9 |    50 |     2 |     0.5625 |
# +-----+------+-------+-------+------------+
# |   4 |    2 |    15 |    15 |     0.125  |
# +-----+------+-------+-------+------------+
# |   5 |   15 |    80 |     0 |     0.9375 |
# +-----+------+-------+-------+------------+
# |   6 |    0 |     5 |     5 |     0      |
# +-----+------+-------+-------+------------+
# |   7 |    5 |    30 |    14 |     0.3125 |
# +-----+------+-------+-------+------------+
# ...
