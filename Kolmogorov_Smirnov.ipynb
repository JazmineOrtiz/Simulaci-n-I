# %% [markdown]
# <a href="https://colab.research.google.com/github/JazmineOrtiz/Simulaci-n-I/blob/main/Kolmogorov_Smirnov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate

datos = [0.8797, 0.3884, 0.6289, 0.8750, 0.5999, 0.8589, 0.9996, 0.2415, 0.3808, 0.9606, 0.9848, 0.3469, 0.7977, 0.5844, 0.8147, 0.6431, 0.7387, 0.5613, 0.0318, 0.7401, 0.4557, 0.1592, 0.8536, 0.8846, 0.3410, 0.1492, 0.8681, 0.5291, 0.3188, 0.5992, 0.9170, 0.2204, 0.5991, 0.5461, 0.5739, 0.3254, 0.0856, 0.2258, 0.4603, 0.5027, 0.8376, 0.6235, 0.3681, 0.2088, 0.1525, 0.2006, 0.4720, 0.4272, 0.6360, 0.0954]
datos.sort()
tabla = [["Xi", "D+", "D-"]]
n = len(datos)
Dmax = []
dmax = []
for i, xi in enumerate(datos, start=1):
    D = abs(i / n - xi)
    Dmax.append(D)
for i, xi in enumerate(datos, start=1):
    d = abs(xi - (i - 1) / n)
    dmax.append(d)
    maxD = max(Dmax)
    maxd = max(dmax)
for xi, d_plus, d_minus in zip(datos, Dmax, dmax):
    tabla.append([xi, d_plus, d_minus])
print(tabulate(tabla, tablefmt="grid"))
if maxD >= maxd:
    print("El mayor es:", maxD)
else:
   print("El mayor es:", maxd)
# Out:
# +--------+------------------------+------------------------+
# | Xi     | D+                     | D-                     |
# +--------+------------------------+------------------------+
# | 0.0318 | 0.011800000000000001   | 0.0318                 |
# +--------+------------------------+------------------------+
# | 0.0856 | 0.045599999999999995   | 0.06559999999999999    |
# +--------+------------------------+------------------------+
# | 0.0954 | 0.0354                 | 0.0554                 |
# +--------+------------------------+------------------------+
# | 0.1492 | 0.0692                 | 0.0892                 |
# +--------+------------------------+------------------------+
# | 0.1525 | 0.05249999999999999    | 0.0725                 |
# +--------+------------------------+------------------------+
# | 0.1592 | 0.03920000000000001    | 0.0592                 |
# +--------+------------------------+------------------------+
# ...
